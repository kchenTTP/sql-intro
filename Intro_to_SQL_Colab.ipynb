# %% [markdown]
# <a href="https://colab.research.google.com/github/kchenTTP/sql-intro/blob/main/Intro_to_SQL_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Intro to SQL**
#
# Structured Query Language (SQL) is a domain-specific programming language that allow us to store, retrieve, and manipulate data in structured relational databases.

# %% [markdown]
# ---
#
# ## **Keyword Definition**
#
# **Structured Data**: Data that has a predefined format (schema or data model) and fits neatly into a tabular structure. It is organized and easy to store, process, and analyze using traditional database systems.
#   - Databases
#   - Spreadsheet
#
# **Database**: A structured collection of data organized and managed in a specific way.
#
# **Table**: A collection of related data organized in rows and columns.
#
# **Relationship**: An association between tables based on common attributes, such as `primary key` and `foreign keys`.
#
# **Primary Key**: A unique identifier for each row in a table, used to ensure data integrity and establish relationships with other tables.
#
# **Foreign Key**: A column that refers to the primary key of another table, establishing a relationship between the two tables.

# %% [markdown]
# ---
#
# ## **Preparing Our Workspace**
#
# Since SQL is a language working with databases. To write SQL, we will typically need a **database management system** and a **SQL client**.

# %% [markdown]
# ### *Database Management System (DBMS)*
#
# A software system that provides tools and services to manage databases. There are several different database management systems out there and we sometimes refer to them as different SQL flavors or dialects. The most popular SQL dialects are:
#   - MySQL
#   - PostgreSQL
#   - SQLite
#   - Microsoft SQL Server
#
# > 💡 We will be working with a database file _(chinook.db)_ using SQLite. Let's download the file for today's class first:

# %%
import requests
import os

def gdrive_download(file_id: str, save_path: str) -> None:
  if os.path.exists(save_path):
    os.remove(db_path)

  print(f"Downloading file: '{file_id}'", end="", flush=True)

  url = f"https://drive.google.com/uc?export=download&id={file_id}"

  with requests.Session() as session:
    with session.get(url, stream=True) as res:
      res.raise_for_status()
      with open(save_path, "wb") as f:
        for chunk in res.iter_content(chunk_size=32768):
          if chunk:
            f.write(chunk)
            print(".", end="", flush=True)

  print(f"\nFile saved at '{save_path}'!")

def validate_file(file_path: str):
  print(f"Validating '{file_path}': ", end="", flush=True)
  with open(file_path, "rb") as f:
    header = f.read(15)
    if header != b"SQLite format 3":
      preview = header.decode("utf-8")
      print(preview)
      raise TypeError(f"'{file_path}' is not a valid SQLite database.")

  print(f"SQLite 3.x database")

# %%
db_path = "./chinook.db"
file_id = "1iDtcj6o4nv9cJZMezjRFPP2mDIVxqETv"
url = f"https://drive.google.com/uc?export=download&id={file_id}"

gdrive_download(file_id, db_path)
validate_file(db_path)

# %% [markdown]
# ### *SQL Client*
#
# A tool or interface that allows you to connect to a DBMS and execute SQL queries. This can be a command-line interface (CLI), a graphical user interface (GUI), a web-based interface, or some code.

# %% [markdown]
# #### *Setup Helper Functions*
#
# Since we're using Python to connect to our SQL Database, let's set up some helper functions.
#
# > 📒 **NOTE:** Understanding Python is not required for this class but these 3 functions are required to interact with a SQL database.
#
# - **`show_tables`**: Show all table names in database
# - **`show_table_info`**: Show column information of a table
# - **`query`**: Query the database
#
# > ❗ Run this cell to set up sqlite helper functions!

# %%
# @title
import sqlite3
import pandas as pd
from IPython.display import display, HTML


def query(sql_query: str, db: str = db_path):
  with sqlite3.connect(db) as conn:
    cursor = conn.cursor()
    cursor.execute(sql_query)
    results = cursor.fetchall()

    column_names = [description[0] for description in cursor.description]
    df = pd.DataFrame(results, columns=column_names)

    display(HTML(df.to_html(index=False)))

def show_tables(db: str = db_path):
  sql = "SELECT name as table_name FROM sqlite_master WHERE type='table' AND name not in ('sqlite_sequence', 'sqlite_stat1');"
  query(sql, db)

def show_table_info(table_name: str, db: str = db_path):
  sql = f"PRAGMA table_info({table_name});"
  query(sql, db)

# %% [markdown]
# ### Explore the Database

# %%
# Look at the tables in the database
show_tables()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>table_name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>albums</td>
#     </tr>
#     <tr>
#       <td>artists</td>
#     </tr>
#     <tr>
#       <td>customers</td>
#     </tr>
#     <tr>
#       <td>employees</td>
#     </tr>
#     <tr>
#       <td>genres</td>
#     </tr>
#     <tr>
#       <td>invoices</td>
#     </tr>
#     <tr>
#       <td>invoice_items</td>
#     </tr>
#     <tr>
#       <td>media_types</td>
#     </tr>
#     <tr>
#       <td>playlists</td>
#     </tr>
#     <tr>
#       <td>playlist_track</td>
#     </tr>
#     <tr>
#       <td>tracks</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Change the name to any other table to look at the column names and info of that table
show_table_info("customers")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>cid</th>
#       <th>name</th>
#       <th>type</th>
#       <th>notnull</th>
#       <th>dflt_value</th>
#       <th>pk</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>CustomerId</td>
#       <td>INTEGER</td>
#       <td>1</td>
#       <td>None</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>FirstName</td>
#       <td>NVARCHAR(40)</td>
#       <td>1</td>
#       <td>None</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>LastName</td>
#       <td>NVARCHAR(20)</td>
#       <td>1</td>
#       <td>None</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>Company</td>
#       <td>NVARCHAR(80)</td>
#       <td>0</td>
#       <td>None</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>Address</td>
#       <td>NVARCHAR(70)</td>
#       <td>0</td>
#       <td>None</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>City</td>
#       <td>NVARCHAR(40)</td>
#       <td>0</td>
#       <td>None</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>State</td>
#       <td>NVARCHAR(40)</td>
#       <td>0</td>
#       <td>None</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>Country</td>
#       <td>NVARCHAR(40)</td>
#       <td>0</td>
#       <td>None</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>PostalCode</td>
#       <td>NVARCHAR(10)</td>
#       <td>0</td>
#       <td>None</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>Phone</td>
#       <td>NVARCHAR(24)</td>
#       <td>0</td>
#       <td>None</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>Fax</td>
#       <td>NVARCHAR(24)</td>
#       <td>0</td>
#       <td>None</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>Email</td>
#       <td>NVARCHAR(60)</td>
#       <td>1</td>
#       <td>None</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>SupportRepId</td>
#       <td>INTEGER</td>
#       <td>0</td>
#       <td>None</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ---
#
# ## **SQL Keywords**

# %% [markdown]
# ### `SELECT`
#
# Which columns in a table to select, required keyword when performing queries.
#
# > Note: Use special character _**`*`**_ to select every column.

# %%
sql = "select 1.0 / 2;"
query(sql)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>1.0 / 2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.5</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### `FROM`
#
# From which table we are selecting the columns.

# %%
sql = "select * from genres;"
query(sql)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>GenreId</th>
#       <th>Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>Rock</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>Jazz</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>Metal</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>Alternative &amp; Punk</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>Rock And Roll</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>Blues</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>Latin</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>Reggae</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>Pop</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>Soundtrack</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>Bossa Nova</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>Easy Listening</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>Heavy Metal</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>R&amp;B/Soul</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>Electronica/Dance</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>World</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>Hip Hop/Rap</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>Science Fiction</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>TV Shows</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>Sci Fi &amp; Fantasy</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>Drama</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>Comedy</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>Alternative</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>Classical</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>Opera</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### `AS`
#
# Use `AS` to create aliases for columns.
#
# **Syntax:**
# ```
# SELECT column1 AS alias1, column2 AS alias2
# FROM table;
# ```

# %%
sql = """select InvoiceDate as Date, BillingCountry as Country, Total
from invoices;"""
query(sql)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Date</th>
#       <th>Country</th>
#       <th>Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2009-01-01 00:00:00</td>
#       <td>Germany</td>
#       <td>1.98</td>
#     </tr>
#     <tr>
#       <td>2009-01-02 00:00:00</td>
#       <td>Norway</td>
#       <td>3.96</td>
#     </tr>
#     <tr>
#       <td>2009-01-03 00:00:00</td>
#       <td>Belgium</td>
#       <td>5.94</td>
#     </tr>
#     <tr>
#       <td>2009-01-06 00:00:00</td>
#       <td>Canada</td>
#       <td>8.91</td>
#     </tr>
#     <tr>
#       <td>2009-01-11 00:00:00</td>
#       <td>USA</td>
#       <td>13.86</td>
#     </tr>
#     <tr>
#       <td>2009
td>
#       <td>1.98</td>
#     </tr>
#     <tr>
#       <td>2009-11-08 00:00:00</td>
#       <td>Canada</td>
#       <td>3.96</td>
#     </tr>
#     <tr>
#       <td>2009-11-09 00:00:00</td>
#       <td>Portugal</td>
#       <td>5.94</td>
#     </tr>
#     <tr>
#       <td>2009-11-12 00:00:00</td>
#       <td>France</td>
#       <td>8.91</td>
#     </tr>
#     <tr>
#       <td>2009-11-17 00:00:00</td>
#       <td>Poland</td>
#       <td>13.86</td>
#     </tr>
#     <tr>
#       <td>2009-11-25 00:00:00</td>
#       <td>Norway</td>
#       <td>0.99</td>
#     </tr>
#     <tr>
#       <td>2009-12-08 00:00:00</td>
#       <td>Czech Republic</td>
#       <td>1.98</td>
#     </tr>
#     <tr>
#       <td>2009-12-08 00:00:00</td>
#       <td>Austria</td>
#       <td>1.98</td>
#     </tr>
#     <tr>
#       <td>2009-12-09 00:00:00</td>
#       <td>Denmark</td>
#       <td>3.96</td>
#     </tr>
#     <tr>
#       <td>2009-12-10 00:00:00</td>
#       <td>Brazil</td>
#       <td>5.94</td>
#     </tr>
#     <tr>
#       <td>2009-12-13 00:00:00</td>
#       <td>USA</td>
#       <td>8.91</td>
#     </tr>

# %% [markdown]
# ### `DISTINCT`
#
# Removes duplicate rows from the result, leaving only unique values.
#
# **Syntax:**
# ```
# SELECT DISTINCT column1, column2, ...
# FROM table;
# ```

# %%
sql = """select distinct
BillingCountry, BillingCity
from invoices;"""
query(sql)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>BillingCountry</th>
#       <th>BillingCity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Germany</td>
#       <td>Stuttgart</td>
#     </tr>
#     <tr>
#       <td>Norway</td>
#       <td>Oslo</td>
#     </tr>
#     <tr>
#       <td>Belgium</td>
#       <td>Brussels</td>
#     </tr>
#     <tr>
#       <td>Canada</td>
#       <td>Edmonton</td>
#     </tr>
#     <tr>
#       <td>USA</td>
#       <td>Boston</td>
#     </tr>
#     <tr>
#       <td>Germany</td>
#       <td>Frankfurt</td>
#     </tr>
#     <tr>
#       <td>Germany</td>
#       <td>Berlin</td>
#     </tr>
#     <tr>
#       <td>France</td>
#       <td>Paris</td>
#     </tr>
#     <tr>
#       <td>France</td>
#       <td>Bordeaux</td>
#     </tr>
#     <tr>
#       <td>Ireland</td>
#       <td>Dublin</td>
#     </tr>
#     <tr>
#       <td>United Kingdom</td>
#       <td>London</td>
#     </tr>
#     <tr>
#       <td>USA</td>
#       <td>Mountain View</td>
#     </tr>
#     <tr>
#       <td>USA</td>
#       <td>Redmond</td>
#     </tr>
#     <tr>
#       <td>USA</td>
#       <td>Cupertino</td>
#     </tr>
#     <tr>
#       <td>USA</td>
#       <td>Reno</td>
#     </tr>
#     <tr>
#       <td>USA</td>
#       <td>Madison</td>
#     </tr>
#     <tr>
#       <td>Canada</td>
#       <td>Halifax</td>
#     </tr>
#     <tr>
#       <td>United Kingdom</td>
#       <td>Edinburgh</td>
#     </tr>
#     <tr>
#       <td>Australia</td>
#       <td>Sidney</td>
#     </tr>
#     <tr>
#       <td>Chile</td>
#       <td>Santiago</td>
#     </tr>
#     <tr>
#       <td>India</td>
#       <td>Bangalore</td>
#     </tr>
#     <tr>
#       <td>Brazil</td>
#       <td>São Paulo</td>
#     </tr>
#     <tr>
#       <td>Canada</td>
#       <td>Yellowknife</td>
#     </tr>
#     <tr>
#       <td>Portugal</td>
#       <td>Lisbon</td>
#     </tr>
#     <tr>
#       <td>Netherlands</td>
#       <td>Amsterdam</td>
#     </tr>
#     <tr>
#       <td>Brazil</td>
#       <td>Rio de Janeiro</td>
#     </tr>
#     <tr>
#       <td>Brazil</td>
#       <td>Brasília</td>
#     </tr>
#     <tr>
#       <td>Canada</td>
#       <td>Vancouver</td>
#     </tr>
#     <tr>
#       <td>USA</td>
#       <td>Tucson</td>
#     </tr>
#     <tr>
#       <td>Spain</td>
#       <td>Madrid</td>
#     </tr>
#     <tr>
#       <td>Sweden</td>
#       <td>Stockholm</td>
#     </tr>
#     <tr>
#       <td>Czech Republic</td>
#       <td>Prague</td>
#     </tr>
#     <tr>
#       <td>Canada</td>
#       <td>Toronto</td>
#     </tr>
#     <tr>
#       <td>Canada</td>
#       <td>Ottawa</td>
#     </tr>
#     <tr>
#       <td>Canada</td>
#       <td>Winnipeg</td>
#     </tr>
#     <tr>
#       <td>Finland</td>
#       <td>Helsinki</td>
#     </tr>
#     <tr>
#       <td>Denmark</td>
#       <td>Copenhagen</td>
#     </tr>
#     <tr>
#       <td>Italy</td>
#       <td>Rome</td>
#     </tr>
#     <tr>
#       <td>Poland</td>
#       <td>Warsaw</td>
#     </tr>
#     <tr>
#       <td>USA</td>
#       <td>Fort Worth</td>
#     </tr>
#     <tr>
#       <td>USA</td>
#       <td>Salt Lake City</td>
#     </tr>
#     <tr>
#       <td>Austria</td>
#       <td>Vienne</td>
#     </tr>
#     <tr>
#       <td>France</td>
#       <td>Dijon</td>
#     </tr>
#     <tr>
#       <td>Hungary</td>
#       <td>Budapest</td>
#     </tr>
#     <tr>
#       <td>USA</td>
#       <td>Orlando</td>
#     </tr>
#     <tr>
#       <td>USA</td>
#       <td>Chicago</td>
#     </tr>
#     <tr>
#       <td>Brazil</td>
#       <td>São José dos Campos</td>
#     </tr>
#     <tr>
#       <td>Canada</td>
#       <td>Montréal</td>
#     </tr>
#     <tr>
#       <td>France</td>
#       <td>Lyon</td>
#     </tr>
#     <tr>
#       <td>USA</td>
#       <td>New York</td>
#     </tr>
#     <tr>
#       <td>Argentina</td>
#       <td>Buenos Aires</td>
#     </tr>
#     <tr>
#       <td>India</td>
#       <td>Delhi</td>
#     </tr>
#     <tr>
#       <td>Portugal</td>
#       <td>Porto</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Try it yourself!
#
# **Excercise**:
#
# > _1. Check out columns `CustomerId`, `FirstName`, `Country` from the `customers` table._
# > _2. Give `CustomerId` an alias called `Id`._

# %%
sql = """your code goes here"""
query(sql)

# %%
#@title Answer
sql = """select
  CustomerId as Id,
  FirstName as Name,
  Country
from customers;"""
query(sql)

# %% [markdown]
# ---
#
# ## **Clauses**
#
# Clauses provide additional instructions to specify various conditions, constraints, or operations within an SQL statement to modify the behavior of the query.

# %% [markdown]
# ### `WHERE`
#
# Filter records based on specified **conditions**. We use comparison operators to define the **condition**:
#
# > ### _Comparison Operators_
# > - `=`   Equal to
# > - `<`   Less than
# > - `>`   Greater than
# > - `<>`  Not equal to
# > - `<=`  Less than or equal to
# > - `>=`  Greater than or equal to
#
# **Syntax:**
# ```
# SELECT column1, column2, ...
# FROM table_name
# WHERE condition;
# ```

# %% [markdown]
# **Only show invoices from Germany**

# %%
sql = """select
    InvoiceDate,
    BillingCountry,
    BillingCity
from invoices
where BillingCountry = 'Germany';"""
query(sql)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>InvoiceDate</th>
#       <th>BillingCountry</th>
#       <th>BillingCity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2009-01-01 00:00:00</td>
#       <td>Germany</td>
#       <td>Stuttgart</td>
#     </tr>
#     <tr>
#       <td>2009-01-19 00:00:00</td>
#       <td>Germany</td>
#       <td>Frankfurt</td>
#     </tr>
#     <tr>
#       <td>2009-02-01 00:00:00</td>
#       <td>Germany</td>
#       <td>Berlin</td>
#     </tr>
#     <tr>
#       <td>2009-02-11 00:00:00</td>
#       <td>Germany</td>
#       <td>Stuttgart</td>
#     </tr>
#     <tr>
#       <td>2009-05-05 00:00:00</td>
#       <td>Germany</td>
#       <td>Berlin</td>
#     </tr>
#     <tr>
#       <td>2009-05-06 00:00:00</td>
#       <td>Germany</td>
#       <td>Berlin</td>
#     </tr>
#     <tr>
#       <td>2009-06-15 00:00:00</td>
#       <td>Germany</td>
#       <td>Berlin</td>
#     </tr>
#     <tr>
#       <td>2009-08-08 00:00:00</td>
#       <td>Germany</td>
#       <td>Berlin</td>
#     </tr>
#     <tr>
#       <td>2009-10-12 00:00:00</td>
#       <td>Germany</td>
#       <td>Stuttgart</td>
#     </tr>
#     <tr>
#       <td>2010-02-13 00:00:00</td>
#       <td>Germany</td>
#       <td>Berlin</td>
#     </tr>
#     <tr>
#       <td>2010-03-29 00:00:00</td>
#       <td>Germany</td>
#       <td>Berlin</td>
#     </tr>
#     <tr>
#       <td>2010-07-13 00:00:00</td>
#       <td>Germany</td>
#       <td>Frankfurt</td>
#     </tr>
#     <tr>
#       <td>2010-08-23 00:00:00</td>
#       <td>Germany</td>
#       <td>Frankfurt</td>
#     </tr>
#     <tr>
#       <td>2011-04-23 00:00:00</td>
#       <td>Germany</td>
#       <td>Frankfurt</td>
#     </tr>
#     <tr>
#       <td>2011-05-19 00:00:00</td>
#       <td>Germany</td>
#       <td>Stuttgart</td>
#     </tr>
#     <tr>
#       <td>2011-08-21 00:00:00</td>
#       <td>Germany</td>
#       <td>Stuttgart</td>
#     </tr>
#     <tr>
#       <td>2011-09-20 00:00:00</td>
#       <td>Germany</td>
#       <td>Berlin</td>
#     </tr>
#     <tr>
#       <td>2011-09-20 00:00:00</td>
#       <td>Germany</td>
#       <td>Berlin</td>
#     </tr>
#     <tr>
#       <td>2011-10-31 00:00:00</td>
#       <td>Germany</td>
#       <td>Berlin</td>
#     </tr>
#     <tr>
#       <td>2011-11-23 00:00:00</td>
#       <td>Germany</td>
#       <td>Stuttgart</td>
#     </tr>
#     <tr>
#       <td>2011-12-23 00:00:00</td>
#       <td>Germany</td>
#       <td>Berlin</td>
#     </tr>
#     <tr>
#       <td>2012-03-26 00:00:00</td>
#       <td>Germany</td>
#       <td>Berlin</td>
#     </tr>
#     <tr>
#       <td>2012-06-30 00:00:00</td>
#       <td>Germany</td>
#       <td>Berlin</td>
#     </tr>
#     <tr>
#       <td>2012-07-13 00:00:00</td>
#       <td>Germany</td>
#       <td>Stuttgart</td>
#     </tr>
#     <tr>
#       <td>2012-11-14 00:00:00</td>
#       <td>Germany</td>
#       <td>Berlin</td>
#     </tr>
#     <tr>
#       <td>2012-11-27 00:00:00</td>
#       <td>Germany</td>
#       <td>Frankfurt</td>
#     </tr>
#     <tr>
#       <td>2013-03-01 00:00:00</td>
#       <td>Germany</td>
#       <td>Frankfurt</td>
#     </tr>
#     <tr>
#       <td>2013-06-03 00:00:00</td>
#       <td>Germany</td>
#       <td>Frankfurt</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### `AND`/ `OR`
#
# Use `AND` and `OR` to add more conditions to your queries.
#
# **Syntax:**
# ```
# condition1 AND condition2
# ```

# %% [markdown]
# **Show invoices from Germany but not from Berlin**

# %%
sql = """select
    InvoiceDate,
    BillingCountry,
    BillingCity
from invoices
where BillingCountry = 'Germany' OR BillingCity <> 'Berlin';
"""
query(sql)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>InvoiceDate</th>
#       <th>BillingCountry</th>
#       <th>BillingCity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2009-01-01 00:00:00</td>
#       <td>Germany</td>
#       <td>Stuttgart</td>
#     </tr>
#     <tr>
#       <td>2009-01-02 00:00:00</td>
#       <td>Norway</td>
#       <td>Oslo</td>
#     </tr>
#     <tr>
#       <td>2009-01-03 00:00:00</td>
#       <td>Belgium</td>
#       <td>Brussels</td>
#     </tr>
#     <tr>
#       <td>2009-01-06 00:00:00</td>
#       <td>Canada</td>
#       <td>Edmonton</td>
#     </tr>
#     <tr>
#       <td>2009-01-11 00:00:00</td>
#       <td>USA</td>
#       <td>Boston</td>
#     </tr>
#     <tr>
#       <td>2009-01-19 00:00:00</td>
#       <td>Germany</td>
#       <td>Frankfurt</td>
#     </tr>
#     <tr>
#       <td>2009-02-01 00:00:00</td>
#       <td>Germany</td>
#       <td>Berlin</td>
#     </tr>
#     <tr>
#       <td>2009-02-01 00:00:00</td>
#       <td>France</td>
#       <td>Paris</td>
#     </tr>
#     <tr>
#       <td>2009-02-02 00:00:00</td>
#       <td>France</td>
#       <td>Bordeaux</td>
#     </tr>
#     <tr>
#       <td>2009-02-03 00:00:00</td>
#       <td>Ireland</td>
#       <td>Dublin</td>
#     </tr>
#     <tr>
#       <td>2009-02-06 00:00:00</td>
#       <td>United Kingdom</td>
#       <td>London</td>
#     </tr>
#     <tr>
#       <td>2009-02-11 00:00:00</td>
#       <td>Germany</td>
#       <td>Stuttgart</td>
#     </tr>
#     <tr>
#       <td>2009-02-19 00:00:00</td>
#       <td>USA</td>
#       <td>Mountain View</td>
#     </tr>
#     <tr>
#       <td>2009-03-04 00:00:00</td>
#       <td>USA</td>
#       <td>Redmond</td>
#     </tr>
#     <tr>
#       <td>2009-03-04 00:00:00</td>
#       <td>USA</td>
#       <td>Cupertino</td>
#     </tr>
#     <tr>
#       <td>2009-03-05 00:00:00</td>
#       <td>USA</td>
#       <td>Reno</td>
#     </tr>
#     <tr>
#       <td>2009-03-06 00:00:00</td>
#       <td>USA</td>
#       <td>Madison</td>
#     </tr>
#     <tr>
#       <td>2009-03-09 00:00:00</td>
#       <td>Canada</td>
#       <td>Halifax</td>
#     </tr>
#     <tr>
#       <td>2009-03-14 00:00:00</td>
#       <td>France</td>
#       <td>Paris</td>
#     </tr>
#     <tr>
#       <td>2009-03-22 00:00:00</td>
#       <td>United Kingdom</td>
#       <td>Edinburgh</td>
#     </tr>
#     <tr>
#       <td>2009-04-04 00:00:00</td>
#       <td>Australia</td>
#       <td>Sidney</td>
#     </tr>
#     <tr>
#       <td>2009-04-04 00:00:00</td>
#       <td>Chile</td>
#       <td>Santiago</td>
#     </tr>
#     <tr>
#       <td>2009-04-05 00:00:00</td>
#       <td>India</td>
#       <td>Bangalore</td>
#     </tr>
#     <tr>
#       <td>2009-04-06 00:00:00</td>
#       <td>Norway</td>
#       <td>Oslo</td>
#     </tr>
#     <tr>
#       <td>2009-04-09 00:00:00</td>
#       <td>Brazil</td>
#       <td>São Paulo</td>
#     </tr>
#     <tr>
#       
td>
#       <td>São Paulo</td>
#     </tr>
#     <tr>
#       <td>2009-09-07 00:00:00</td>
#       <td>Brazil</td>
#       <td>Brasília</td>
#     </tr>
#     <tr>
#       <td>2009-09-08 00:00:00</td>
#       <td>USA</td>
#       <td>Redmond</td>
#     </tr>
#     <tr>
#       <td>2009-09-11 00:00:00</td>
#       <td>USA</td>
#       <td>Boston</td>
#     </tr>
#     <tr>
#       <td>2009-09-16 00:00:00</td>
#       <td>Canada</td>
#       <td>Winnipeg</td>
#     </tr>
#     <tr>
#       <td>2009-09-24 00:00:00</td>
#       <td>Ireland</td>
#       <td>Dublin</td>
#     </tr>
#     <tr>
#       <td>2009-10-07 00:00:00</td>
#       <td>Italy</td>
#       <td>Rome</td>
#     </tr>
#     <tr>
#       <td>2009-10-07 00:00:00</td>
#       <td>Poland</td>
#       <td>Warsaw</td>
#     </tr>
#     <tr>
#       <td>2009-10-08 00:00:00</td>
#       <td>Sweden</td>
#       <td>Stockholm</td>
#     </tr>
#     <tr>
#       <td>2009-10-09 00:00:00</td>
#       <td>Australia</td>
#       <td>Sidney</td>
#     </tr>
#     <tr>
#       <td>2009-10-12 00:00:00</td>
#       <td>Germany</td>
#       <td>Stuttgart</td>
#     </tr>
#     <tr>
#       <td>2009-10-17 00:00:00</td>
#       <td>Brazil</td>
#       <td>São Paulo</td>
#     </tr>
#     <tr>
#       <td>2009-10-25 00:00:00</td>
#       <td>USA</td>
#       <td>Madison</td>
#     </tr>
#     <tr>
#       <td>2009-11-07 00:00:00</td>
#       <td>USA</td>
#       <td>Fort Worth</td>
#     </tr>
#     <tr>
#       <td>2009-11-07 00:00:00</td>
#       <td>USA</td>
#       <td>Salt Lake City</td>
#     </tr>
#     <tr>
#       <td>2009-11-08 00:00:00</td>
#       <td>Canada</td>
#       <td>Ottawa</td>
#     </tr>
#     <tr>
#       <td>2009-11-09 00:00:00</td>
#       <td>Portugal</td>
#       <td>Lisbon</td>
#     </tr>
#     <tr>
#       <td>2009-11-12 00:00:00</td>
#       <td>France</td>
#       <td>Paris</td>
#     </tr>
#     <tr>
#       <td>2009-11-17 00:00:00</td>
#       <td>Poland</td>
#       <td>Warsaw</td>
#     </tr>
#     <tr>
#       <td>2009-11-25 00:00:00</td>
#       <td>Norway</td>
#       <td>Oslo</td>
#     </tr>
#     <tr>
#       <td>2009-12-08 00:00:00</td>
#       <td>Czech Republic</td>
#       <td>Prague</td>
#     </tr>
#     <tr>
#       <td>2009-12-08 00:00:00</td>
#       <td>Austria</td>
#       <td>Vienne</td>
#     </tr>
#     <tr>
#       <td>200

# %% [markdown]
# ### `BETWEEN`
# Used to specify a range of values for comparison.
#
# **Syntax:**
# ```
# column_name BETWEEN value1 AND value2
# ```

# %% [markdown]
# **Show album sales between 2010 and 2012**

# %%
sql = """select date(InvoiceDate) as Date, CustomerId, Total
from invoices
where date(InvoiceDate) between '2010' AND '2012';"""
query(sql)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>
td>
#       <td>8.91</td>
#     </tr>
#     <tr>
#       <td>2010-11-24</td>
#       <td>33</td>
#       <td>13.86</td>
#     </tr>
#     <tr>
#       <td>2010-12-02</td>
#       <td>47</td>
#       <td>0.99</td>
#     </tr>
#     <tr>
#       <td>2010-12-15</td>
#       <td>48</td>
#       <td>1.98</td>
#     </tr>
#     <tr>
#       <td>2010-12-15</td>
#       <td>50</td>
#       <td>1.98</td>
#     </tr>
#     <tr>
#       <td>2010-12-16</td>
#       <td>52</td>
#       <td>3.96</td>
#     </tr>
#     <tr>
#       <td>2010-12-17</td>
#       <td>56</td>
#       <td>5.94</td>
#     </tr>
#     <tr>
#       <td>2010-12-20</td>
#       <td>3</td>
#       <td>8.91</td>
#     </tr>
#     <tr>
#       <td>2010-12-25</td>
#       <td>12</td>
#       <td>13.86</td>
#     </tr>
#     <tr>
#       <td>2011-01-02</td>
#       <td>26</td>
#       <td>0.99</td>
#     </tr>
#     <tr>
#       <td>2011-01-15</td>
#       <td>27</td>
#       <td>1.98</td>
#     </tr>
#     <tr>
#       <td>2011-01-15</td>
#       <td>29</td>
#       <td>1.98</td>
#     </tr>
#     <tr>
#       <td>2011-01-16</td>
#       <td>31</td>
#       <td>3.96</td>
#     </tr>
#     <tr>
#       <td>2011-01-17</td>
#       <td>35</td>
#       <td>5.94</td>
#     </tr>
#     <tr>
#       <td>2011-01-20</td>
#       <td>41</td>
#       <td>8.91</td>
#     </tr>
#     <tr>
#       <td>2011-01-25</td>
#       <td>50</td>
#       <td>13.86</td>
#     </tr>
#     <tr>
#       <td>2011-02-02</td>
#       <td>5</td>
#       <td>0.99</td>
#     </tr>
#     <tr>
#       <td>2011-02-15</td>
#       <td>6</td>
#       <td>1.98</td>
#     </tr>
#     <tr>
#       <td>2011-02-15</td>
#       <td>8</td>
#       <td>1.98</td>
#     </tr>
#     <tr>
#       <td>2011-02-16</td>
#       <td>10</td>
#       <td>3.96</td>
#     </tr>
#     <tr>
#       <td

# %% [markdown]
# ### `IN`
#
# Allows you to match a column's value against a list of specified values.
#
# **Syntax:**
# ```
# column_name IN (value1, value2, ...)
# ```

# %% [markdown]
# **Find employees who are in manager positions**

# %%
sql = """select
    FirstName || ' ' || LastName as name,
    Title
from employees
where Title in ('General Manager', 'Sales Manager', 'IT Manager');"""
# where Title LIKE '% Manager';
query(sql)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>name</th>
#       <th>Title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Andrew Adams</td>
#       <td>General Manager</td>
#     </tr>
#     <tr>
#       <td>Nancy Edwards</td>
#       <td>Sales Manager</td>
#     </tr>
#     <tr>
#       <td>Michael Mitchell</td>
#       <td>IT Manager</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### _Functions_
#
# Functions are pre-defined operations that perform specific computations or transformations on data.
#
# #### [**`date(timestring, [modifiters], [...])`**](https://www.sqlitetutorial.net/sqlite-date-functions/sqlite-date-function/)
# The `date()` function accepts a time string and zero or more modifiers as arguments. It returns a date string in this format: **`YYYY-MM-DD`**.
#
# #### [**`string1 || string2`**](https://www.sqlitetutorial.net/sqlite-string-functions/sqlite-concat/)
# Concatenate two strings into a single string. Can be chained together to concatenate more than 2 strings.

# %% [markdown]
# ### Try it yourself!
#
# **Excercise**:
#
# **_Find invoices from USA or Canada where the total amount spent is greater than $8_**
# > _Show  **`InvoiceId`**, **`InvoiceDate`**, **`BillingCountry`**, **`Total`**  columns from the **`invoices`** table._

# %%
sql = """your code goes here"""
query(sql)

# %%
#@title Answer
sql = """select InvoiceId, InvoiceDate, BillingCountry, Total
from invoices
where BillingCountry in ('USA', 'Canada') and Total > 8;"""
query(sql)

# %% [markdown]
# ---
# ### `GROUP BY`
#
# Group rows based on one or more columns into subgroups. Typically used in conjunction with **_aggregate functions_** to perform calculations or summary operations on groups of rows.
#
# **Syntax:**
# ```
# SELECT column1, column2, ..., aggregate_function(column)
# FROM table_name
# GROUP BY column1, column2, ...;
# ```

# %% [markdown]
# ### _Aggregate Functions_
# Functions that operate on a set of rows and calculate a single value as the result.

# %% [markdown]
# #### `COUNT(column)`
#
# Counts the number of rows in a column.

# %% [markdown]
# **Count the number of employees in different titles**

# %%
sql = """select
    Title,
    count(*) as Number
from employees
group by Title;"""
query(sql)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Title</th>
#       <th>Number</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>General Manager</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>IT Manager</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>IT Staff</td>
#       <td>2</td>
#     </tr>
#     <tr>
#       <td>Sales Manager</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <td>Sales Support Agent</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### `SUM(column)`
#
# Sums up the numerical values in a column.

# %% [markdown]
# **Show yearly sale numbers**

# %%
sql = """select
    strftime('%Y', InvoiceDate) as year,
    sum(Total) as total
from invoices
group by year;"""
query(sql)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>year</th>
#       <th>total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2009</td>
#       <td>449.46</td>
#     </tr>
#     <tr>
#       <td>2010</td>
#       <td>481.45</td>
#     </tr>
#     <tr>
#       <td>2011</td>
#       <td>469.58</td>
#     </tr>
#     <tr>
#       <td>2012</td>
#       <td>477.53</td>
#     </tr>
#     <tr>
#       <td>2013</td>
#       <td>450.58</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### `ORDER BY`
#
# Change the order of appearance.
#
# **Syntax:**
# ```
# ORDER BY column sorting_order
# ```
#
# > - **sorting_order**:
# >   - **ASC**: Ascending order
# >   - **DESC**: Descending order
#
# ### `LIMIT`
#
# Limit the amount of output to the specified number.
#
# **Syntax:**
# ```
# LIMIT number
# ```

# %%
sql = """select Name
from artists
order by name desc
limit 10;"""
query(sql)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Name</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Zeca Pagodinho</td>
#     </tr>
#     <tr>
#       <td>Youssou N'Dour</td>
#     </tr>
#     <tr>
#       <td>Yo-Yo Ma</td>
#     </tr>
#     <tr>
#       <td>Yehudi Menuhin</td>
#     </tr>
#     <tr>
#       <td>Xis</td>
#     </tr>
#     <tr>
#       <td>Wilhelm Kempff</td>
#     </tr>
#     <tr>
#       <td>Whitesnake</td>
#     </tr>
#     <tr>
#       <td>Vinícius E Qurteto Em Cy</td>
#     </tr>
#     <tr>
#       <td>Vinícius E Odette Lara</td>
#     </tr>
#     <tr>
#       <td>Vinícius De Moraes &amp; Baden Powell</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Try it yourself!
#
# **Excercise 1**:
#
# **_Find top 10 artists that have the most amount of tracks_**
# > _1. Show the `Composer` and the number of tracks they have._
# > _2. Remove `NULL` values._
# >
# > _Hint: Use the `tracks` table._

# %%
sql = """your code goes here"""
query(sql)

# %%
#@title Answer
sql = """select Composer, count(*) as n_tracks
from tracks
where Composer is not null
group by Composer
order by n_tracks desc
limit 10;"""
query(sql)

# %% [markdown]
# **Excercise 2**:
#
# **_Find artists that have the top 10 longest track_**
# > _1. Show the `Composer` and the length of their longest track tracks (`Milliseconds`)._
# > _2. Remove `NULL` values._
# >
# > _Hint: Use the `tracks` table._

# %%
sql = """your code goes here"""
query(sql)

# %%
#@title Answer
sql = """select Composer, max(Milliseconds) as Milliseconds
from tracks
where Composer is not null
group by Composer
order by Milliseconds desc
limit 10;"""
query(sql)

# %% [markdown]
# ---
#
# ## **Joins**
#
# Joins are used to combine rows from two tables based on related columns that has **matching values**. Commonly, joins are performed when there is a relationship between tables, such as a **primary key** in one table that corresponds to a **foreign key** in another table.
#
# ### _Join Condition_
#
# By specifying the columns used to link the tables, or the _**join condition**_, you can create a result set that includes data from multiple tables as per the defined relationship.
#
# <br>
#
# <figure align="center">
#   <img src="https://raw.githubusercontent.com/kchenTTP/sql-intro/refs/heads/main/assets/sql-joins.jpg" alt="SQL Joins" />
#   <figcaption>The 4 kinds of SQL Joins<figcaption>
# </figure>

# %% [markdown]
# ### `INNER JOIN`
#
# Returns only the rows that have matching values in both tables.
#
# **Syntax:**
# ```
# SELECT t1.column1, t2.column2
# FROM table1 t1
# INNER JOIN table2 t2 ON t1.id = t2.id;
# ```

# %% [markdown]
# **Show customers that have spent the most amount of money**

# %%
sql = """select
    c.FirstName || ' ' || c.LastName as name,
    sum(i.Total) as total_spent,
    count(i.InvoiceDate) as n_times_shopped
from customers c
inner join invoices i on c.CustomerId = i.CustomerId
group by name
order by total_spent desc;"""
query(sql)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>name</th>
#       <th>total_spent</th>
#       <th>n_times_shopped</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Helena Holý</td>
#       <td>49.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Richard Cunningham</td>
#       <td>47.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Luis Rojas</td>
#       <td>46.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Ladislav Kovács</td>
#       <td>45.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Hugh O'Reilly</td>
#       <td>45.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Julia Barnett</td>
#       <td>43.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Fynn Zimmermann</td>
#       <td>43.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Frank Ralston</td>
#       <td>43.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Victor Stevens</td>
#       <td>42.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Astrid Gruber</td>
#       <td>42.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Terhi Hämäläinen</td>
#       <td>41.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Isabelle Mercier</td>
#       <td>40.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>František Wichterlová</td>
#       <td>40.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Johannes Van der Berg</td>
#       <td>40.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>João Fernandes</td>
#       <td>39.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Jack Smith</td>
#       <td>39.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Wyatt Girard</td>
#       <td>39.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Luís Gonçalves</td>
#       <td>39.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Heather Leacock</td>
#       <td>39.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>François Tremblay</td>
#       <td>39.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Dan Miller</td>
#       <td>39.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Bjørn Hansen</td>
#       <td>39.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Tim Goyer</td>
#       <td>38.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Manoj Pareek</td>
#       <td>38.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Joakim Johansson</td>
#       <td>38.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Jennifer Peterson</td>
#       <td>38.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Dominique Lefebvre</td>
#       <td>38.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Camille Bernard</td>
#       <td>38.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Stanisław Wójcik</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Phil Hughes</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Patrick Gray</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Niklas Schröder</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Michelle Brooks</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Martha Silk</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Mark Taylor</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Mark Philips</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Marc Dubois</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Madalena Sampaio</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Lucas Mancini</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Leonie Köhler</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Kara Nielsen</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Hannah Schneider</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Fernanda Ramos</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Emma Jones</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Edward Francis</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Eduardo Martins</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Diego Gutiérrez</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Alexandre Rocha</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Aaron Mitchell</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Steve Murray</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Roberto Almeida</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Robert Brown</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Kathy Chase</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>John Gordon</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Frank Harris</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Enrique Muñoz</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Ellie Sullivan</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Daan Peeters</td>
#       <td>37.62</td>
#       <td>7</td>
#     </tr>
#     <tr>
#       <td>Puja Srivastava</td>
#       <td>36.64</td>
#       <td>6</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Try it yourself!
#
# **Excercise**:
#
# **_Find top 20 artists that sold the most amount of tracks_**
#
# > _Hint:_
# > *1. Both `invoice_items` and `tracks` table have a column named `TrackId`.*
# > _2. Use `GROUP BY` to group rows into subgroups of `Composers`._
# > *3. Each row in `invoice_items` is one sale.*
# > _4. Remove `NULL` values._

# %%
sql = """your code goes here"""
query(sql)

# %%
#@title Answer
sql = """select
t.Composer as artist,
count(ii.InvoiceId) as n_tracks_bought
from invoice_items ii
join tracks t on t.TrackId = ii.TrackId
where t.composer is not null
group by artist
order by n_tracks_bought desc
limit 20;"""
query(sql)

# %% [markdown]
# ### `LEFT JOIN`
#
# Returns the rows that have matching values in both tables and every row on the left table.
#
# **Syntax:**
# ```
# SELECT t1.column1, t2.column2
# FROM table1 t1
# LEFT JOIN table2 t2 ON t1.id = t2.id;
# ```
#
# ### `RIGHT JOIN`
#
# Returns the rows that have matching values in both tables and every row on the right table.
#
# **Syntax:**
# ```
# SELECT t1.column1, t2.column2
# FROM table1 t1
# RIGHT JOIN table2 t2 ON t1.id = t2.id;
# ```

# %% [markdown]
# **Show the least popular artists in the record store**
#
# > _💡 Without using `LEFT JOIN`, we won't be able to see artists with 0 sales. Since only the ones who have sold tracks will have a record in the `invoiceitems` table_

# %%
sql = """select
    t.Composer as artist,
    count(ii.InvoiceId) as n_tracks_bought
from tracks t
left join invoice_items ii on t.TrackId = ii.TrackId
where t.composer is not null
group by artist
order by n_tracks_bought asc;"""
query(sql)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>artist</th>
#       <th>n_tracks_bought</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>A. Jamal</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Aaron Copland</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Aaron Goldberg</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Acyr Marques/Arlindo Cruz/Franco</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Adrian Smith/Bruce Dickinson/Nicko McBrain</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Adrian Vanderberg/David Coverdale</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Adriano Bernandes/Edmar Neves</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Alba Carvalho/Fernando Porto</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Albert King</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Alcides Dias Lopes</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Alcino Corrêa/Monarco</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Alex North/Hy Zaret</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Alexandre Brazil/Pedro Luis/Rodrigo Cabelo</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Allen Story/George Gordy/Robert Gordy</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Almir Guineto/Dedé Paraiso/Luverci Ernesto</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Amos Blakemore/Buddy Guy</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Andrea Dulbecco</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Anonymous</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Antonio Carlos Jobim</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Antonio Lopes</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Antonio Vivaldi</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Arlindo Cruz/Carlos Sena/Elmo Caetano/Mauricao</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Arnaldo Antunes</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Arnaldo Antunes/Britto, SergioMiklos, Paulo</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Arnaldo Anutnes/Marcelo Fromer/Paulo Miklos</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Arnaldo Baptista - Rita Lee</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Augusto Conceição/Chiclete Com Banana</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Augusto Garcez/Nelson Cavaquinho</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Augusto/Craig Negoescu/Rocco Filho/Saara, Ze Carlos Da</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>B. de Filippi - F. Migliaci - Versão: Fred Jorge</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Bahiano/Chuck Rio/Diego Blanco/Herbert Vianna</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Bahiano/Diego Blanco/Herbert Vianna</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Barrett Strong/Norman Whitfield</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Barrett Strong/Norman Whitfield/Roger Penzabene</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Ben Shepherd/Chris Cornell</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Bernardo Vilhena/Bino Farias/Da Gama/Lazão/Toni Garrido</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Bernardo Vilhena/Bino/Da Gama/Lazao/Toni Garrido</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Bernardo Vilhena/Da Gama/Lazao</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Bert Russell/Phil Medley</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Beto Guedes, Ronaldo Bastos</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Beto Guedes/Fernando Brant/L Borges</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Bill Dees/Roy Orbison</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Bino Farias/Da Gama/Lazão/Pedro Luis/Toni Garrido</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Bino Farias/Da Gama/Lazão/Rás Bernardo</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Bino/Da Gamma/Lazao/Toni Garrido</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Black Sabbath</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Blackmore/Coverdale</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Blackmore/Coverdale/Lord/Paice</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Blackmore/Gillan/Glover/Lord/Paice</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Blaze Bayley/David Murray/Steve Harris</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Bo Diddley</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Bob Cochran/Sharon Sheeley</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Bob Dylan</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Bolin/Hughes</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Bolin/Hughes/Lord</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Bombom/Ed Motta</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Bono</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Brian Eno/U2</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Brian Holland/Freddie Gorman/Georgia Dobbins/Robert Bateman/William Garrett</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Bryan Adams/Nikki Sixx/Scott Humphrey</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Buchanan, Wallis</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>C. Burnett</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>C. Cester</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>C. Cester/C. Muncey</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Caetano Veloso - Gilberto Gil</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Cal Adan/Ferrugem/Julinho Carioca/Tríona Ní Dhomhnaill</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Cale/Clapton</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Carl Orff</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Carlinhos Brown</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Carlos Santana &amp; C. Thompson</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Carlos Santos/Ciro/Claudio Russo/Zé Luiz</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Carolyn Franklin and Sonny Saunders</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Cassiano Costa/Cintia Maviane/J.F./Lucas Costa</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Cave</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Charles Bobbitt/James Brown</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Charles Gavin/Marcelo Fromer/Sérgio Britto</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Chester Burnett/Jimmy Page/John Bonham/John Paul Jones/Robert Plant</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Chico Amaral/Lelo Zanettik</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Cidade Negra</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Clapton/Collins/Pappalardi</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Clarke/Kilmister/Tayler</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Claudio Martins/David Lima/Kleber Rodrigues/Livre, Cesare Som</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Claudio Monteverdi</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Cook/Coverdale</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Corumbá/José Gumarães/Venancio</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Coverdale/Hughes/Lord/Paice</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>D. DeLeo/Kretz/R. DeLeo/Weiland</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>D. DeLeo/R. DeLeo/Weiland</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>D.Coverdal/G.Hughes/Glenn Hughes/I.Paice/Ian Paice/J.Lord/John Lord</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>D.Coverdale/G.Hughes/Glenn Hughes/J.Lord/John Lord</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Da Gama/Lazao/Toni Garrido</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Da Gama/Lazão/Rás Bernardo</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Da Gama/Toni Garrido</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Dado Villa-Lobos</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Dado Villa-Lobos/Ico Ouro-Preto/Marcelo Bonfá</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Dale Evans</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Daniel Lanois</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <td>Dave Abbruzzes

# %% [markdown]
# ### Try it yourself!
#
# **Excercise**:
#
# **_Find the most popular genre and least popular genre in the store_**
#
# > _Hint:_
# > _1.Popularity is based on how many times a track of a genre is bought._
# > *2. `invoice_items` table contains data on the tracks associated with invoices.*
# > _3. `tracks` table has a `GenreId` foreign key from `genres` table, which contains the genre names._
# > _4. Use `GROUP BY` to group rows into subgroups of `Genres`._
# > _5. Be aware of genres that does not have any sales._

# %%
sql = """your code goes here"""
query(sql)

# %%
#@title Answer
sql = """select distinct
  g.Name as genre,
  count(ii.InvoiceId) as n_tracks_bought
from genres g
join tracks t on t.GenreId = g.GenreId
left join invoice_items as ii on t.TrackId = ii.TrackId
group by genre
order by n_tracks_bought desc;"""
query(sql)

# %% [markdown]
# ### `FULL OUTER JOIN`
#
# Returns the rows that have matching values in both tables and every single row in both tables.
#
# **Syntax:**
# ```
# SELECT t1.column1, t2.column2
# FROM table1 t1
# FULL OUTER JOIN table2 t2 ON t1.id = t2.id;
# ```

# %% [markdown]
# > 🚨 Unfortunately, full outer join is not supported by the Python `sqlite3` library yet.

# %% [markdown]
# **Show every artist and track, and match track to artist if there is a match**

# %%
# sql = """select
#   a.Name as Artist,
#   t.Composer,
#   t.Name as Track
# from artists a
# full outer join tracks t
# on a.Name = t.Composer;"""
# query(sql)

# %% [markdown]
# ---
#
# ## **Resources**
#
# For more information on Sqlite, please visit [SQLite Tutorial](https://www.sqlitetutorial.net/) or [SQLite Documentation](https://www.sqlite.org/docs.html)

# %% [markdown]
# ---
#
# ## **Class Survey**
#
# Directly below is a link to a survey that lets us know how we're doing and any additional feedback you might have. Please take some time to fill out the survey in full so that we can learn how to better serve you.
#
# [**Survey Link**](https://docs.google.com/forms/d/e/1FAIpQLSeRoFsj9kC436jyBuImwv2QToGSYYZDo1SygTEnsQ-k3ozHng/viewform)
